# %% [markdown]
# ### Problem statement
#
# Clustering: K-Means
#
# We have given a collection of 8 points. P1=[0.1,0.6] P2=[0.15,0.71]
# P3=[0.08,0.9] P4=[0.16, 0.85] P5=[0.2,0.3] P6=[0.25,0.5]
# P7=[0.24,0.1] P8=[0.3,0.2].
#
# Perform the k-mean clustering with initial centroids
# as m1=P1 =Cluster#1=C1 and m2=P8=cluster#2=C2.
# Answer the following
# 1]
# Which cluster does P6 belongs to?
# 2] What is the population of a cluster around
# m2?
# 3]
# What is the updated value of m1 and m2?

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
points = np.array([
    [0.1, 0.6], [0.15, 0.71], [0.08, 0.9], [0.16, 0.85],
    [0.2, 0.3], [0.25, 0.5], [0.24, 0.1], [0.3, 0.2]
])

# %%
#initial centroids|
m1 = np.array([0.1, 0.6])
m2 = np.array([0.3, 0.2])

# %%
kmeans = KMeans(n_clusters=2, init=np.array([m1, m2]), n_init=1)
kmeans.fit(points)
# Out:
# KMeans(init=array([[0.1, 0.6],
#        [0.3, 0.2]]), n_clusters=2, n_init=1)

# %%
cluster_labels = kmeans.predict(points)

# %%
cluster_labels
# Out:
# array([0, 0, 0, 0, 1, 0, 1, 1])

# %%
plt.scatter(points[cluster_labels == 0, 0], points[cluster_labels == 0, 1], c='blue', label='Cluster 1')
plt.scatter(points[cluster_labels == 1, 0], points[cluster_labels == 1, 1], c='red', label='Cluster 2')

# Plot the centroids
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='black', marker='x', s=100, label='Centroids')

# Plot m1 and m2 as initial centroids
plt.scatter(m1[0], m1[1], c='green', marker='o', s=100, label='Initial m1')
plt.scatter(m2[0], m2[1], c='yellow', marker='o', s=100, label='Initial m2')

# Labels and legend
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('KMeans Clustering')
plt.legend()
plt.grid(True)

# %%
# Answers to the questions
# 1. Which cluster does P6 belong to?
point_p6 = np.array([[0.25, 0.5]])
cluster_p6 = kmeans.predict(point_p6)
print(f"P6 belongs to Cluster: {cluster_p6[0] + 1}")  # Adding 1 to start cluster numbering from 1

# 2. Population of a cluster around m2
population_m2 = np.sum(cluster_labels == 1)  # Assuming the cluster label for m2 is 1
print(f"Population of the cluster around m2: {population_m2}")

# 3. Updated values of m1 and m2 (Centroids)
centroids = kmeans.cluster_centers_
print(f"Updated value of m1: {centroids[0]}")
print(f"Updated value of m2: {centroids[1]}")
# Out:
# P6 belongs to Cluster: 1
# Population of the cluster around m2: 3
# Updated value of m1: [0.148 0.712]
# Updated value of m2: [0.24666667 0.2       ]
